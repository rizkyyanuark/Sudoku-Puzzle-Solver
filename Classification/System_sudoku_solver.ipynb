# %%
# !gdown "1ur4CrYKZT197pOCdZCSt-7DabXbcp-x_"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ur4CrYKZT197pOCdZCSt-7DabXbcp-x_
# To: c:\Users\rizky\OneDrive\Dokumen\GitHub\SudokuSolverDariCitraDigital\kaggle.json
#
#   0%|          | 0.00/63.0 [00:00<?, ?B/s]
# 100%|██████████| 63.0/63.0 [00:00<?, ?B/s]

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# The syntax of the command is incorrect.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'chmod' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !kaggle datasets download -d macfooty/sudoku-box-detection
# !kaggle datasets download -d karnikakapoor/digits
# !kaggle datasets download -d karnikakapoor/su-puzzle
# Out:
# 'kaggle' is not recognized as an internal or external command,
# operable program or batch file.
# 'kaggle' is not recognized as an internal or external command,
# operable program or batch file.
# 'kaggle' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !unzip su-puzzle.zip -d /content/dataset
# !unzip sudoku-box-detection.zip -d /content/dataset
# !unzip digits.zip -d /content/dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00081.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00082.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00083.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00084.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00085.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00086.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00087.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00088.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00089.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00090.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00091.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00092.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00093.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00094.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00095.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00096.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00097.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00098.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00099.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00100.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00101.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00102.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00103.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00104.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00105.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00106.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00107.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00108.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00109.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00110.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00111.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00112.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00113.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00114.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00115.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00116.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00117.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00118.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00119.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00120.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00121.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00122.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00123.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00124.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00125.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00126.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00127.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00128.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00129.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00130.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00131.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00132.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00133.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00134.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00135.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00136.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00137.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00138.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00139.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00140.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00141.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00142.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00143.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00144.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00145.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00146.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00147.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00148.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00149.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00150.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00151.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00152.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00153.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00154.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00155.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00156.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00157.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00158.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00159.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00160.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00161.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00162.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00163.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00164.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00165.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00166.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00167.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00168.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00169.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00170.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00171.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00172.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00173.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00174.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00175.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00176.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00177.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00178.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00179.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00180.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00181.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00182.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00183.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00184.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00185.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00186.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00187.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00188.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00189.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00190.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00191.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00192.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00193.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00194.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00195.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00196.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00197.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00198.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00199.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00200.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00201.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00202.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00203.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00204.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00205.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00206.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00207.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00208.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00209.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00210.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00211.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00212.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00213.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00214.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00215.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00216.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00217.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00218.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00219.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00220.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00221.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00222.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00223.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00224.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00225.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00226.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00227.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00228.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00229.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00230.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00231.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00232.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00233.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00234.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00235.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00236.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00237.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00238.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00239.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00240.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00241.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00242.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00243.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00244.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00245.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00246.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00247.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00248.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00249.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00250.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00251.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00252.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00253.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00254.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00255.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00256.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00257.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00258.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00259.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00260.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00261.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00262.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00263.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00264.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00265.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00266.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00267.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00268.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00269.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00270.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00271.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00272.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00273.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00274.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00275.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00276.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00277.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00278.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00279.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00280.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00281.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00282.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00283.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00284.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00285.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00286.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00287.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00288.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00289.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00290.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00291.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00292.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00293.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00294.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00295.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00296.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00297.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00298.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00299.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00300.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00301.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00302.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00303.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00304.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00305.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00306.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00307.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00308.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00309.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00310.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00311.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00312.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00313.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00314.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00315.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00316.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00317.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00318.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00319.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00320.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00321.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00322.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00323.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00324.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00325.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00326.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00327.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00328.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00329.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00330.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00331.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00332.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00333.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00334.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00335.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00336.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00337.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00338.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00339.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00340.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00341.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00342.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00343.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00344.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00345.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00346.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00347.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00348.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00349.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00350.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00351.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00352.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00353.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00354.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00355.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00356.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00357.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00358.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00359.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00360.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00361.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00362.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00363.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00364.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00365.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00366.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00367.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00368.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00369.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00370.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00371.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00372.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00373.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00374.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00375.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00376.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00377.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00378.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00379.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00380.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00381.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00382.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00383.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00384.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00385.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00386.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00387.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00388.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00389.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00390.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00391.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00392.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00393.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00394.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00395.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00396.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00397.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00398.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00399.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00400.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00401.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00402.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00403.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00404.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00405.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00406.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00407.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00408.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00409.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00410.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00411.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00412.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00413.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00414.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00415.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00416.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00417.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00418.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00419.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00420.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00421.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00422.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00423.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00424.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00425.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00426.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00427.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00428.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00429.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00430.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00431.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00432.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00433.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00434.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00435.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00436.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00437.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00438.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00439.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00440.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00441.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00442.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00443.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00444.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00445.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00446.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00447.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00448.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00449.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00450.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00451.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00452.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00453.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00454.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00455.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00456.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00457.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00458.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00459.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00460.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00461.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00462.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00463.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00464.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00465.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00466.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00467.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00468.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00469.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00470.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00471.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00472.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00473.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00474.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00475.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00476.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00477.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00478.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00479.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00480.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00481.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00482.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00483.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00484.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00485.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00486.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00487.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00488.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00489.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00490.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00491.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00492.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00493.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00494.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00495.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00496.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00497.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00498.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00499.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00500.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00501.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00502.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00503.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00504.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00505.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00506.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00507.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00508.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00509.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00510.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00511.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00512.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00513.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00514.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00515.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00516.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00517.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00518.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00519.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00520.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00521.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00522.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00523.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00524.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00525.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00526.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00527.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00528.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00529.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00530.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00531.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00532.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00533.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00534.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00535.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00536.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00537.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00538.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00539.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00540.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00541.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00542.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00543.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00544.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00545.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00546.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00547.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00548.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00549.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00550.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00551.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00552.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00553.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00554.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00555.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00556.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00557.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00558.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00559.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00560.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00561.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00562.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00563.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00564.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00565.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00566.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00567.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00568.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00569.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00570.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00571.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00572.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00573.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00574.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00575.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00576.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00577.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00578.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00579.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00580.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00581.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00582.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00583.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00584.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00585.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00586.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00587.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00588.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00589.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00590.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00591.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00592.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00593.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00594.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00595.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00596.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00597.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00598.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00599.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00600.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00601.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00602.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00603.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00604.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00605.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00606.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00607.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00608.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00609.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00610.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00611.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00612.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00613.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00614.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00615.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00616.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00617.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00618.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00619.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00620.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00621.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00622.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00623.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00624.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00625.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00626.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00627.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00628.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00629.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00630.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00631.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00632.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00633.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00634.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00635.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00636.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00637.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00638.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00639.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00640.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00641.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00642.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00643.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00644.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00645.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00646.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00647.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00648.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00649.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00650.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00651.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00652.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00653.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00654.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00655.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00656.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00657.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00658.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00659.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00660.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00661.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00662.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00663.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00664.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00665.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00666.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00667.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00668.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00669.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00670.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00671.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00672.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00673.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00674.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00675.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00676.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00677.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00678.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00679.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00680.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00681.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00682.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00683.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00684.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00685.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00686.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00687.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00688.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00689.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00690.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00691.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00692.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00693.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00694.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00695.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00696.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00697.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00698.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00699.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00700.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00701.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00702.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00703.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00704.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00705.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00706.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00707.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00708.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00709.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/5/img006-00710.jpeg
# ...
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00807.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00808.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00809.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00810.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00811.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00812.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00813.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00814.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00815.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00816.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00817.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00818.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00819.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00820.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00821.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00822.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00823.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00824.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00825.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00826.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00827.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00828.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00829.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00830.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00831.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00832.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00833.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00834.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00835.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00836.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00837.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00838.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00839.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00840.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00841.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00842.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00843.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00844.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00845.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00846.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00847.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00848.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00849.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00850.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00851.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00852.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00853.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00854.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00855.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00856.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00857.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00858.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00859.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00860.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00861.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00862.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00863.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00864.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00865.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00866.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00867.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00868.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00869.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00870.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00871.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00872.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00873.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00874.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00875.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00876.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00877.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00878.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00879.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00880.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00881.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00882.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00883.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00884.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00885.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00886.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00887.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00888.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00889.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00890.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00891.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00892.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00893.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00894.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00895.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00896.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00897.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00898.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00899.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00900.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00901.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00902.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00903.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00904.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00905.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00906.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00907.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00908.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00909.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00910.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00911.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00912.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00913.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00914.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00915.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00916.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00917.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00918.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00919.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00920.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00921.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00922.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00923.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00924.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00925.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00926.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00927.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00928.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00929.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00930.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00931.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00932.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00933.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00934.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00935.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00936.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00937.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00938.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00939.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00940.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00941.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00942.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00943.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00944.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00945.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00946.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00947.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00948.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00949.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00950.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00951.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00952.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00953.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00954.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00955.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00956.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00957.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00958.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00959.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00960.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00961.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00962.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00963.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00964.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00965.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00966.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00967.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00968.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00969.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00970.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00971.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00972.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00973.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00974.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00975.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00976.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00977.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00978.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00979.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00980.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00981.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00982.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00983.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00984.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00985.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00986.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00987.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00988.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00989.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00990.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00991.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00992.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00993.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00994.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00995.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00996.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00997.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00998.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-00999.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01000.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01001.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01002.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01003.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01004.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01005.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01006.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01007.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01008.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01009.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01010.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01011.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01012.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01013.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01014.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01015.jpeg
#   inflating: /content/dataset/digits_jpeg/digits_jpeg/9/img010-01016.jpeg

# %%
import os
import kaggle
import zipfile
import logging

def download_kaggle_dataset(dataset: str, dir_name: str = "data") -> None:
    initial_dir = os.getcwd()  # Simpan direktori awal
    if not os.path.isdir(dir_name):
        os.mkdir(dir_name)
    os.chdir(dir_name)
    
    # Download dataset
    kaggle.api.dataset_download_files(dataset, path='.', unzip=True)
    
    os.chdir(initial_dir)  # Kembali ke direktori awal

# Atur logging
logging.basicConfig(level=logging.INFO)

# Panggil fungsi dengan nama dataset Kaggle dan parameter yang sesuai
download_kaggle_dataset("macfooty/sudoku-box-detection", dir_name="sudoku-box-detection")
download_kaggle_dataset("karnikakapoor/digits", dir_name="digits")
download_kaggle_dataset("karnikakapoor/su-puzzle", dir_name="su-puzzle")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/macfooty/sudoku-box-detection
# Dataset URL: https://www.kaggle.com/datasets/karnikakapoor/digits
# Dataset URL: https://www.kaggle.com/datasets/karnikakapoor/su-puzzle

# %% [markdown]
# # <p style="background-color:#006989; font-family:newtimeroman; font-size:250%; text-align:center; border-radius: 15px 50px;color:#F3F7EC">Sudoku Solver</p>

# %% [markdown]
# <a id='0'></a>
# ## <p style="background-color:#F3F7EC; font-family:newtimeroman; font-size:120%; text-align:center; border-radius: 15px 50px; color:#F3F7EC;">[Table of Content](#0)</p>
#
# * [1. Importing Libraries 💎](#1)
# * [2. Digits Classification](#2)
#     * [Integration Data](#3)
#     * [Splitting Test Train And Validation Sets](#4)
#     * [Preprocessing Data](#5)
#     * [Model Building And Training](#6)
# * [3. Detecting Sudoku Puzzle](#7)
#     * [Read an image from the dataset](#8)
#     * [Preprocess the image](#9)
#     * [Detecting Countour](#10)
#     * [Transformation Perspective](#11)
#     * [Split Cels](#12)
# * [4 Solving Sudoku](#13)
#     * [Detecting Box Sudoku](#14)
#     * [Classifying Digits](#15)
#     * [Solve Sudoku](#16)

# %% [markdown]
# <a id="1"></a>
# ## Importing Libraries

# %%
#Loading Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os, random
import cv2
from glob import glob
import sklearn
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Dense, Flatten, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing import image
from sklearn.metrics import accuracy_score, classification_report
from pathlib import Path
from PIL import Image
from keras.models import load_model

# %% [markdown]
# <a id="2"></a>
# ## <p style="background-color:#006989; font-family:newtimeroman; font-size:250%; text-align:center; border-radius: 15px 50px;color:#F3F7EC">Digits Classification</p>

# %% [markdown]
# <a id="3"></a>
# **In this section:**
#
# * Integration Data
# * Splitting Test Train And Validation Sets
# * Preprocessing Data
# * Model Building And Training
#
# <a id="3"></a>
# # **<span style="color:#F3F7EC;">Integration Data</span>**

# %% [markdown]
# ### Dataset Digits

# %%
# Specify the path to the dataset
base_path = r"C:\Users\rizky\Downloads\dataset\digits\digits updated\digits updated"

# Check if the base path exists
if not os.path.exists(base_path):
    print(f"Base path does not exist: {base_path}")
else:
    data = os.listdir(base_path)
    data_X = []
    data_y = []
    data_classes = len(data)

    for i in range(data_classes):
        class_path = os.path.join(base_path, str(i))

        # Check if the class path exists
        if not os.path.exists(class_path):
            print(f"Class path does not exist: {class_path}")
            continue

        data_list = os.listdir(class_path)
        for j in data_list:
            img_path = os.path.join(class_path, j)

            # Check if the image path exists
            if not os.path.exists(img_path):
                print(f"Image path does not exist: {img_path}")
                continue

            pic = cv2.imread(img_path)
            if pic is None:
                print(f"Failed to read image: {img_path}")
                continue

            pic = cv2.resize(pic, (32, 32))
            data_X.append(pic)
            data_y.append(i)

    if len(data_X) == len(data_y):
        print("Total Datapoints = ", len(data_X))
    else:
        print("Mismatch in the number of images and labels")

    # Convert to numpy arrays
    data_X = np.array(data_X)
    data_y = np.array(data_y)
# Out:
# Total Datapoints =  10160

# %% [markdown]
# ### Dataset MNIST

# %%
from keras.datasets import mnist

# Load MNIST dataset
(mnist_train_X, mnist_train_y), (mnist_test_X, mnist_test_y) = mnist.load_data()
# Resize MNIST images to 32x32 and convert to RGB
mnist_train_X = np.stack([cv2.resize(img, (32, 32)) for img in mnist_train_X], axis=0)
mnist_test_X = np.stack([cv2.resize(img, (32, 32)) for img in mnist_test_X], axis=0)
mnist_train_X = np.stack([cv2.cvtColor(img, cv2.COLOR_GRAY2RGB) for img in mnist_train_X], axis=0)
mnist_test_X = np.stack([cv2.cvtColor(img, cv2.COLOR_GRAY2RGB) for img in mnist_test_X], axis=0)

# %%
# Combine the local dataset with MNIST dataset
combined_X = np.concatenate((data_X, mnist_train_X, mnist_test_X), axis=0)
combined_y = np.concatenate((data_y, mnist_train_y, mnist_test_y), axis=0)

# %% [markdown]
# <a id="4"></a>
# # **<span style="color:#F3F7EC;">SPLITTING DATA</span>**

# %%
train_X, test_X, train_y, test_y = train_test_split(combined_X, combined_y, test_size=0.05, random_state=42)
train_X, valid_X, train_y, valid_y = train_test_split(train_X, train_y, test_size=0.2, random_state=42)

print("Training Set Shape = ",train_X.shape)
print("Validation Set Shape = ",valid_X.shape)
print("Test Set Shape = ",test_X.shape)
# Out:
# Training Set Shape =  (60921, 32, 32, 3)
# Validation Set Shape =  (15231, 32, 32, 3)
# Test Set Shape =  (4008, 32, 32, 3)

# %% [markdown]
# <a id="5"></a>
# # **<span style="color:#F3F7EC;">PREPROCESSING DATA</span>**

# %%
# Preprocessing the images for neuralnet

def Prep(img):
    img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) #making image grayscale
    img = cv2.equalizeHist(img) #Histogram equalization to enhance contrast
    img = img/255 #normalizing
    return img

train_X = np.array(list(map(Prep, train_X)))
test_X = np.array(list(map(Prep, test_X)))
valid_X= np.array(list(map(Prep, valid_X)))

#Reshaping the images
train_X = train_X.reshape(train_X.shape[0], train_X.shape[1], train_X.shape[2],1)
test_X = test_X.reshape(test_X.shape[0], test_X.shape[1], test_X.shape[2],1)
valid_X = valid_X.reshape(valid_X.shape[0], valid_X.shape[1], valid_X.shape[2],1)

#Augmentation
datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, zoom_range=0.2, shear_range=0.1, rotation_range=10)
datagen.fit(train_X)

# %%
# One hot encoding of the labels

train_y = to_categorical(train_y, data_classes)
test_y = to_categorical(test_y, data_classes)
valid_y = to_categorical(valid_y, data_classes)

# %% [markdown]
# <a id="6"></a>
# # **<span style="color:#F3F7EC;">MODEL BUILDING AND TRAINING</span>**

# %%
#Creating a Neural Network

model = Sequential()

model.add((Conv2D(60,(5,5),input_shape=(32, 32, 1) ,padding = 'Same' ,activation='relu')))
model.add((Conv2D(60, (5,5),padding="same",activation='relu')))
model.add(MaxPooling2D(pool_size=(2,2)))
#model.add(Dropout(0.25))

model.add((Conv2D(30, (3,3),padding="same", activation='relu')))
model.add((Conv2D(30, (3,3), padding="same", activation='relu')))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(500,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 60)        1560
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 60)        90060
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 60)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 30)        16230
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 30)        8130
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 30)          0
#  g2D)
#
#  dropout (Dropout)           (None, 8, 8, 30)          0
#
#  flatten (Flatten)           (None, 1920)              0
#
#  dense (Dense)               (None, 500)               960500
#
#  dropout_1 (Dropout)         (None, 500)               0
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 1081490 (4.13 MB)
# Trainable params: 1081490 (4.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Compiling the model

optimizer = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

#Fit the model
history = model.fit(datagen.flow(train_X, train_y, batch_size=32),
                              epochs = 30, validation_data = (valid_X, valid_y),
                              verbose = 1, steps_per_epoch= 200)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 200/200 [==============================] - 56s 279ms/step - loss: 1.2399 - accuracy: 0.5811 - val_loss: 0.3035 - val_accuracy: 0.8951
# Epoch 2/30
# 200/200 [==============================] - 53s 266ms/step - loss: 0.5478 - accuracy: 0.8269 - val_loss: 0.1363 - val_accuracy: 0.9558
# Epoch 3/30
# 200/200 [==============================] - 54s 272ms/step - loss: 0.3823 - accuracy: 0.8822 - val_loss: 0.1209 - val_accuracy: 0.9623
# Epoch 4/30
# 200/200 [==============================] - 50s 251ms/step - loss: 0.3125 - accuracy: 0.9056 - val_loss: 0.0819 - val_accuracy: 0.9752
# Epoch 5/30
# 200/200 [==============================] - 49s 247ms/step - loss: 0.3108 - accuracy: 0.9061 - val_loss: 0.1312 - val_accuracy: 0.9571
# Epoch 6/30
# 200/200 [==============================] - 47s 234ms/step - loss: 0.2556 - accuracy: 0.9275 - val_loss: 0.0714 - val_accuracy: 0.9780
# Epoch 7/30
# 200/200 [==============================] - 48s 241ms/step - loss: 0.2389 - accuracy: 0.9269 - val_loss: 0.0689 - val_accuracy: 0.9779
# Epoch 8/30
# 200/200 [==============================] - 49s 243ms/step - loss: 0.2033 - accuracy: 0.9380 - val_loss: 0.0668 - val_accuracy: 0.9777
# Epoch 9/30
# 200/200 [==============================] - 51s 253ms/step - loss: 0.1988 - accuracy: 0.9364 - val_loss: 0.0614 - val_accuracy: 0.9812
# Epoch 10/30
# 200/200 [==============================] - 53s 265ms/step - loss: 0.1901 - accuracy: 0.9430 - val_loss: 0.0612 - val_accuracy: 0.9806
# Epoch 11/30
# 200/200 [==============================] - 52s 258ms/step - loss: 0.1842 - accuracy: 0.9453 - val_loss: 0.0531 - val_accuracy: 0.9837
# Epoch 12/30
# 200/200 [==============================] - 51s 255ms/step - loss: 0.1717 - accuracy: 0.9484 - val_loss: 0.0585 - val_accuracy: 0.9812
# Epoch 13/30
# 200/200 [==============================] - 52s 258ms/step - loss: 0.1838 - accuracy: 0.9445 - val_loss: 0.0540 - val_accuracy: 0.9837
# Epoch 14/30
# 200/200 [==============================] - 50s 252ms/step - loss: 0.1455 - accuracy: 0.9569 - val_loss: 0.0541 - val_accuracy: 0.9835
# Epoch 15/30
# 200/200 [==============================] - 49s 246ms/step - loss: 0.1620 - accuracy: 0.9536 - val_loss: 0.0479 - val_accuracy: 0.9849
# Epoch 16/30
# 200/200 [==============================] - 69s 348ms/step - loss: 0.1398 - accuracy: 0.9581 - val_loss: 0.0566 - val_accuracy: 0.9836
# Epoch 17/30
# 200/200 [==============================] - 67s 335ms/step - loss: 0.1565 - accuracy: 0.9548 - val_loss: 0.0532 - val_accuracy: 0.9837
# Epoch 18/30
# 200/200 [==============================] - 62s 309ms/step - loss: 0.1543 - accuracy: 0.9552 - val_loss: 0.0431 - val_accuracy: 0.9869
# Epoch 19/30
# 200/200 [==============================] - 59s 296ms/step - loss: 0.1339 - accuracy: 0.9611 - val_loss: 0.0393 - val_accuracy: 0.9877
# Epoch 20/30
# 200/200 [==============================] - 60s 298ms/step - loss: 0.1344 - accuracy: 0.9586 - val_loss: 0.0549 - val_accuracy: 0.9840
# Epoch 21/30
# 200/200 [==============================] - 60s 300ms/step - loss: 0.1497 - accuracy: 0.9545 - val_loss: 0.0449 - val_accuracy: 0.9854
# Epoch 22/30
# 200/200 [==============================] - 60s 301ms/step - loss: 0.1387 - accuracy: 0.9594 - val_loss: 0.0477 - val_accuracy: 0.9857
# Epoch 23/30
# 200/200 [==============================] - 66s 333ms/step - loss: 0.1488 - accuracy: 0.9560 - val_loss: 0.0477 - val_accuracy: 0.9848
# Epoch 24/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9584
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 7
#       4 model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])
#       6 #Fit the model
# ----> 7 history = model.fit(datagen.flow(train_X, train_y, batch_size=32),
#       8                               epochs = 30, validation_data = (valid_X, valid_y),
#       9                               verbose = 1, steps_per_epoch= 200)
#
# File c:\Users\rizky\anaconda3\envs\ML\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\rizky\anaconda3\envs\ML\lib\site-packages\keras\src\engine\training.py:1791, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1775 if getattr(self, "_eval_data_handler", None) is None:
#    1776     self._eval_data_handler = data_adapter.get_data_handler(
#    1777         x=val_x,
#    1778         y=val_y,
#    (...)
#    1789         pss_evaluation_shards=self._pss_evaluation_shards,
#    1790     )
# -> 1791 val_logs = self.evaluate(
#    1792     x=val_x,
#    1793     y=val_y,
#    1794     sample_weight=val_sample_weight,
#    1795     batch_size=validation_batch_size or batch_size,
#    1796     steps=validation_steps,
#    1797     callbacks=callbacks,
#    1798     max_queue_size=max_queue_size,
#    1799     workers=workers,
#    1800     use_multiprocessing=use_multiprocessing,
#    1801     return_dict=True,
#    1802     _use_cached_eval_dataset=True,
#    1803 )
#    1804 val_logs = {
#    1805     "val_" + name: val for name, val in val_logs.items()
#    1806 }
#    1807 epoch_logs.update(val_logs)
#
# File c:\Users\rizky\anaconda3\envs\ML\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\rizky\anaconda3\envs\ML\lib\site-packages\keras\src\engine\training.py:2200, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2196             with tf.profiler.experimental.Trace(
#    2197                 "test", step_num=step, _r=1
#    2198             ):
#    2199                 callbacks.on_test_batch_begin(step)
# -> 2200                 logs = test_function_runner.run_step(
#    2201                     dataset_or_iterator,
#    2202                     data_handler,
#    2203                     step,
#    2204                     self._pss_evaluation_shards,
#    2205                 )
#    2207 logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    2208 # Override with model metrics instead of last step logs
#
# File c:\Users\rizky\anaconda3\envs\ML\lib\site-packages\keras\src\engine\training.py:4000, in _TestFunction.run_step(self, dataset_or_iterator, data_handler, step, unused_shards)
#    3999 def run_step(self, dataset_or_iterator, data_handler, step, unused_shards):
# -> 4000     tmp_logs = self._function(dataset_or_iterator)
#    4001     if data_handler.should_sync:
#    4002         context.async_wait()
#
# File c:\Users\rizky\anaconda3\envs\ML\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\rizky\anaconda3\envs\ML\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\rizky\anaconda3\envs\ML\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:864, in Function._call(self, *args, **kwds)
#     861 self._lock.release()
#     862 # In this case we have not created variables on the first call. So we can
#     863 # run the first trace but we should fail if variables are created.
# --> 864 results = self._variable_creation_fn(*args, **kwds)
#     865 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     866   raise ValueError("Creating variables on a non-first call to a function"
#     867                    " decorated with tf.function.")
#
# File c:\Users\rizky\anaconda3\envs\ML\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File c:\Users\rizky\anaconda3\envs\ML\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\rizky\anaconda3\envs\ML\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File c:\Users\rizky\anaconda3\envs\ML\lib\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File c:\Users\rizky\anaconda3\envs\ML\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# Testing the model on the test set

score = model.evaluate(test_X, test_y, verbose=0)
print('Test Score = ',score[0])
print('Test Accuracy =', score[1])
# Out:
# Test Score =  0.05311502143740654
# Test Accuracy = 0.9860279560089111

# %%
# Plot the loss and accuracy curves for training and validation
fig, ax = plt.subplots(2,1)
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="Validation loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[1].legend(loc='best', shadow=True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# Predict the values from the validation dataset
y_pred = model.predict(valid_X)

# Convert predictions classes to one hot vectors
y_pred_classes = np.argmax(y_pred, axis=1)

# Convert validation observations to one hot vectors
y_true = np.argmax(valid_y, axis=1)

# Compute the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred_classes)

# Plot the confusion matrix using ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_mtx)
disp.plot(cmap='Blues', values_format='d')

plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 476/476 [==============================] - 12s 25ms/step

# %%
import tensorflow as tf
# Save the model
model.save('my_model.h5')
# Out:
# c:\Users\rizky\anaconda3\envs\myml\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the saved model
model = load_model('models/my_model.h5')

# %% [markdown]
# <a id="7"></a>
# ## <p style="background-color:#006989; font-family:newtimeroman; font-size:250%; text-align:center; border-radius: 15px 50px;color:#F3F7EC">Reading Sudoku Puzzle</p>

# %% [markdown]
# **In this section:**
#
# * Read an image from the dataset
# * Preprocess the image
# * Detecting Countour
# * Transformation Perspective
# * Split Cels

# %%
# Randomly select an image from the dataset

folder=r"C:\Users\rizky\Downloads\aug"

a=random.choice(os.listdir(folder))
print(a)
sudoku_a = cv2.imread(folder+'/'+a)
plt.figure()
plt.imshow(sudoku_a)
plt.show()
# Out:
# _98_4877013.jpeg

# %% [markdown]
# <a id="8"></a>
# # **<span style="color:#F3F7EC;">PREPROCESS IMAGE</span>**

# %%
#Preprocessing image to be read
sudoku_a = cv2.imread(sudoku_a)
sudoku_a = cv2.resize(sudoku_a, (450,450))

# function to greyscale, blur and change the receptive threshold of image
def preprocess(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (3,3),6)
    blur = cv2.bilateralFilter(gray,9,75,75)
    threshold_img = cv2.adaptiveThreshold(blur,255,1,1,11,2)
    return threshold_img

threshold = preprocess(sudoku_a)

#let's look at what we have got
plt.figure()
plt.imshow(threshold)
plt.show()

# %% [markdown]
# <a id="9"></a>
# # **<span style="color:#F3F7EC;">DETECTING CONTOUR</span>**

# %%
# Finding the outline of the sudoku puzzle in the image
contour_1 = sudoku_a.copy()
contour, hierarchy = cv2.findContours(threshold,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(contour_1, contour,-1,(0,255,0),3)

#let's see what we got
plt.figure()
plt.imshow(contour_1)
plt.show()

# %% [markdown]
# <a id="10"></a>
# # **<span style="color:#F3F7EC;">Transformation Perspective</span>**

# %%
def main_outline(contour):
    biggest = np.array([])
    max_area = 0
    for i in contour:
        area = cv2.contourArea(i)
        if area >50:
            peri = cv2.arcLength(i, True)
            approx = cv2.approxPolyDP(i , 0.02* peri, True)
            if area > max_area and len(approx) ==4:
                biggest = approx
                max_area = area
    return biggest ,max_area

def reframe(points):
    points = points.reshape((4, 2))
    points_new = np.zeros((4,1,2),dtype = np.int32)
    add = points.sum(1)
    points_new[0] = points[np.argmin(add)]
    points_new[3] = points[np.argmax(add)]
    diff = np.diff(points, axis =1)
    points_new[1] = points[np.argmin(diff)]
    points_new[2] = points[np.argmax(diff)]
    return points_new


black_img = np.zeros((450,450,3), np.uint8)
biggest, maxArea = main_outline(contour)
if biggest.size != 0:
    biggest = reframe(biggest)
    cv2.drawContours(contour_2,biggest,-1, (0,255,0),10)
    pts1 = np.float32(biggest)
    pts2 = np.float32([[0,0],[450,0],[0,450],[450,450]])
    matrix = cv2.getPerspectiveTransform(pts1,pts2)
    imagewrap = cv2.warpPerspective(sudoku_a,matrix,(450,450))
    imagewrap =cv2.cvtColor(imagewrap, cv2.COLOR_BGR2GRAY)

plt.figure()
plt.imshow(imagewrap,cmap='gray')
plt.show()

# %% [markdown]
# <a id="11"></a>
# # **<span style="color:#F3F7EC;">SPLIT CELS</span>**

# %%
def splitcells(img):
    rows = np.vsplit(img, 9)
    boxes = []
    for r in rows:
        cols = np.hsplit(r, 9)
        for box in cols:
            # Reduce noise
            denoised_box = cv2.fastNlMeansDenoising(box, None, 30, 7, 21)
            # Convert to black and white
            _, bw_box = cv2.threshold(denoised_box, 128, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
            boxes.append(bw_box)
    return boxes

# %%
sudoku_cell = splitcells(imagewrap)
#Let's have alook at the last cell
plt.figure()
plt.imshow(sudoku_cell[2])
plt.show()

# %%
def CropCell(cells):
    Cells_croped = []
    for image in cells:

        img = np.array(image)
        img = img[4:46, 6:46]
        img = Image.fromarray(img)
        Cells_croped.append(img)

    return Cells_croped

sudoku_cell_croped= CropCell(sudoku_cell)
#Let's have alook at the last cell
plt.figure()
plt.imshow(sudoku_cell_croped[2])
plt.show()

# %% [markdown]
# <a id="12"></a>
# ## <p style="background-color:#006989; font-family:newtimeroman; font-size:250%; text-align:center; border-radius: 15px 50px;color:#F3F7EC">Solving Sudoku</p>

# %% [markdown]
# **In this section:**
#
# * Real Image Sudoku
# * Detecting Box Sudoku
# * Classifying Sudoku Digits
# * Solve Sudoku

# %% [markdown]
# <a id="3"></a>
# # **<span style="color:#F3F7EC;">SUDOKU IMAGE</span>**

# %%
# Importing puzzle to be solved
puzzle = r"captured Image1.jpg"

# puzzle=random.choice(os.listdir(folder_2))
# print(puzzle)
puzzle = cv2.imread(puzzle)
plt.figure()
plt.imshow(puzzle)
plt.show()

# %% [markdown]
# <a id="13"></a>
# # **<span style="color:#F3F7EC;">DETECTING BOX SUDOKU</span>**

# %%
# Resizing puzzle to be solved
puzzle = cv2.resize(puzzle, (450,450))
# Preprocessing Puzzle
su_puzzle = preprocess(puzzle)

# Finding the outline of the sudoku puzzle in the image
su_contour_1= su_puzzle.copy()
su_contour_2= su_puzzle.copy()
su_contour, hierarchy = cv2.findContours(su_puzzle,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(su_contour_1, su_contour,-1,(0,255,0),3)

black_img = np.zeros((450,450,3), np.uint8)
su_biggest, su_maxArea = main_outline(su_contour)
if su_biggest.size != 0:
    su_biggest = reframe(su_biggest)
    cv2.drawContours(su_contour_2,su_biggest,-1, (0,255,0),10)
    su_pts1 = np.float32(su_biggest)
    su_pts2 = np.float32([[0,0],[450,0],[0,450],[450,450]])
    su_matrix = cv2.getPerspectiveTransform(su_pts1,su_pts2)
    su_imagewrap = cv2.warpPerspective(puzzle,su_matrix,(450,450))
    su_imagewrap =cv2.cvtColor(su_imagewrap, cv2.COLOR_BGR2GRAY)

plt.figure()
plt.imshow(su_imagewrap)
plt.show()

# %%
sudoku_cell = splitcells(su_imagewrap)
#Let's have alook at the last cell
plt.figure()
plt.imshow(sudoku_cell[7])
plt.show()

# %%
def CropCell(cells):
    Cells_croped = []
    for image in cells:

        img = np.array(image)
        img = img[4:46, 6:46]
        img = Image.fromarray(img)
        Cells_croped.append(img)

    return Cells_croped

sudoku_cell_croped= CropCell(sudoku_cell)
#Let's have alook at the last cell
plt.figure()
plt.imshow(sudoku_cell_croped[1])
plt.show()

# %% [markdown]
# <a id="14"></a>
# # **<span style="color:#F3F7EC;">CLASSIFYING SUDOKU DIGITS</span>**

# %%
def read_cells(cell,model):

    result = []
    for image in cell:
        # preprocess the image as it was in the model
        img = np.asarray(image)
        img = img[4:img.shape[0] - 4, 4:img.shape[1] -4]
        img = cv2.resize(img, (32, 32))
        img = img / 255
        img = img.reshape(1, 32, 32, 1)
        # getting predictions and setting the values if probabilities are above 65%

        predictions = model.predict(img)
        classIndex = np.argmax(predictions, axis=-1)
        probabilityValue = np.amax(predictions)

        if probabilityValue > 0.65:
            result.append(classIndex[0])
        else:
            result.append(0)
    return result

grid = read_cells(sudoku_cell_croped, model)
grid = np.asarray(grid)
# Out:
# 1/1 [==============================] - 0s 457ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
# Reshaping the grid to a 9x9 matrix
grid = np.reshape(grid,(9,9))
grid
# Out:
# array([[0, 7, 0, 0, 2, 0, 0, 4, 6],
#        [0, 6, 0, 0, 0, 0, 8, 9, 0],
#        [2, 0, 0, 8, 0, 0, 7, 1, 5],
#        [0, 8, 4, 0, 9, 7, 0, 0, 0],
#        [7, 1, 0, 0, 0, 0, 0, 5, 9],
#        [0, 0, 0, 1, 3, 0, 4, 8, 0],
#        [6, 9, 7, 0, 0, 2, 0, 0, 8],
#        [0, 5, 8, 0, 0, 0, 0, 6, 0],
#        [4, 3, 0, 0, 8, 0, 0, 7, 0]], dtype=int64)

# %%
#For compairing
plt.figure()
plt.imshow(su_imagewrap)
plt.show()

# %% [markdown]
# <a id="15"></a>
# # **<span style="color:#F3F7EC;">SOLVE SUDOKU</span>**

# %%
# Function to find the next empty box to solve
def next_box(quiz):
    for row in range(9):
        for col in range(9):
            if quiz[row][col] == 0:
                return (row, col)
    return False

# Function to check if a value n can be placed at quiz[row][col]
def possible(quiz, row, col, n):
    for i in range(9):
        if quiz[row][i] == n:
            return False
    for i in range(9):
        if quiz[i][col] == n:
            return False
        
    row0 = (row // 3) * 3
    col0 = (col // 3) * 3
    for i in range(row0, row0 + 3):
        for j in range(col0, col0 + 3):
            if quiz[i][j] == n:
                return False
    return True

# Recursion function to loop until a valid solution is found
def solve(quiz):
    val = next_box(quiz)
    if val is False:
        return True
    else:
        row, col = val
        for n in range(1, 10):
            if possible(quiz, row, col, n):
                quiz[row][col] = n
                if solve(quiz):
                    return True
                quiz[row][col] = 0
        return False

# Function to print the solved quiz
def Solved(quiz):
    for row in range(9):
        if row % 3 == 0 and row != 0:
            print("....................")

        for col in range(9):
            if col % 3 == 0 and col != 0:
                print("|", end=" ")

            if col == 8:
                print(quiz[row][col])
            else:
                print(str(quiz[row][col]) + " ", end="")

# %%
solve(grid)
# Out:
# True

# %%
import time
# Measure the computation time using time.perf_counter()
start_time = time.perf_counter()
if solve(grid):
    end_time = time.perf_counter()
    print("Sudoku solved successfully!")
    Solved(grid)
else:
    end_time = time.perf_counter()
    print("No solution exists for the given Sudoku puzzle.")

computation_time_ms = (end_time - start_time) * 1000
print(f"Computation time: {computation_time_ms:.6f} milliseconds")
# Out:
# Sudoku solved successfully!
# 8 7 5 | 9 2 1 | 3 4 6
# 3 6 1 | 7 5 4 | 8 9 2
# 2 4 9 | 8 6 3 | 7 1 5
# ....................
# 5 8 4 | 6 9 7 | 1 2 3
# 7 1 3 | 2 4 8 | 6 5 9
# 9 2 6 | 1 3 5 | 4 8 7
# ....................
# 6 9 7 | 4 1 2 | 5 3 8
# 1 5 8 | 3 7 9 | 2 6 4
# 4 3 2 | 5 8 6 | 9 7 1
# Computation time: 0.132200 milliseconds

# %%
import matplotlib.pyplot as plt

# Data preparation
images = ['captured image1', 'captured image2', 'captured image3', 'captured image4']
times = [0.058800, 0.062200, 0.054200, 0.057800]

# Create the bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(images, times, color='skyblue')

# Add labels and title
plt.xlabel('Image Names')
plt.ylabel('Computation Time (seconds)')
plt.title('Computation Time for Different Images')
plt.ylim(0, 0.07)  # Set y-axis limit for better readability

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add value labels on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, f'{yval:.6f}', va='bottom')  # va: vertical alignment

# Display the chart
plt.show()
